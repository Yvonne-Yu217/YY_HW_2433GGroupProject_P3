# %% [markdown]
# # Read healthcare.gov CSVs
#
# This notebook reads the four CSV files located in `data/healthcare.gov` and displays the first five rows of each file.

# %%
# Read and display first five rows of the four healthcare.gov CSVs
from pathlib import Path
import pandas as pd
from IPython.display import display

base = Path("data/healthcare.gov")
files = {
    "benefits_and_cost_sharing": "benefits-and-cost-sharing-puf.csv",
    "plan_attributes": "Plan_Attributes_PUF.csv",
    "rate": "Rate_PUF.csv",
    "service_area": "service-area-puf.csv",
}

for key, fname in files.items():
    path = base / fname
    print(f"=== {fname} ===")
    if not path.exists():
        print(f"File not found: {path}\n")
        continue
    try:
        df = pd.read_csv(path, low_memory=False)
        display(df.head(5))
    except Exception as e:
        print(f"Error reading {path}: {e}\n")

# -------------------------------------------------
# Continued analysis specifically for Rate_PUF.csv
# -------------------------------------------------
rate_path = base / files['rate']
if rate_path.exists():
    try:
        print("\n=== Analysis: Rate_PUF.csv ===")
        df_rate = pd.read_csv(rate_path, low_memory=False)

        # Basic overview
        print("Shape:", df_rate.shape)
        print("\nFirst 5 rows:")
        display(df_rate.head(5))

        # Info (prints to stdout in notebooks)
        print("\nInfo:")
        df_rate.info()

        # Missing values (percent)
        print("\nMissing values (percent):")
        missing = (df_rate.isna().mean() * 100).sort_values(ascending=False)
        display(missing[missing > 0].head(20))

        # Numeric summary
        numcols = df_rate.select_dtypes(include='number').columns.tolist()
        if numcols:
            print("\nNumeric summary (describe):")
            display(df_rate[numcols].describe().T)
        else:
            print("\nNo numeric columns found.")

        # Categorical top values
        objcols = df_rate.select_dtypes(include='object').columns.tolist()
        if objcols:
            print("\nTop value counts for object columns (showing up to 10):")
            for col in objcols:
                vc = df_rate[col].value_counts(dropna=False)
                print(f"\nColumn: {col} — unique={vc.size}")
                display(vc.head(10))
        else:
            print("\nNo object (categorical) columns found.")

        # Try to find any 'rate'-like numeric columns and show top rows
        rate_like = [c for c in df_rate.columns if 'rate' in c.lower()]
        if rate_like:
            print(f"\nFound rate-like columns: {rate_like}")
            for c in rate_like:
                if c in numcols:
                    print(f"\nTop 5 rows by {c}:")
                    display(df_rate.nlargest(5, columns=c)[[c] + df_rate.columns[:4].tolist()])
                else:
                    print(f"\nColumn {c} found but it's not numeric; showing value counts:")
                    display(df_rate[c].value_counts(dropna=False).head(10))
        else:
            print("\nNo column name containing 'rate' found; showing top 3 numeric columns by max value instead:")
            if numcols:
                maxvals = {c: df_rate[c].max() for c in numcols}
                sorted_cols = sorted(maxvals, key=maxvals.get, reverse=True)[:3]
                for c in sorted_cols:
                    print(f"\nTop 5 by {c} (max={maxvals[c]}):")
                    display(df_rate.nlargest(5, columns=c)[[c]])

        # Sample rows with most numeric data present
        if numcols:
            numeric_nonnull = df_rate[numcols].notnull().sum(axis=1)
            print('\nSample 5 rows with highest count of non-null numeric values:')
            display(df_rate.loc[numeric_nonnull.nlargest(5).index].head())

    except Exception as e:
        print(f"Error analyzing {rate_path}: {e}")
else:
    print(f"Rate file not found at {rate_path}")
# Out:
# === benefits-and-cost-sharing-puf.csv ===
#    BusinessYear StateCode  IssuerId SourceName           ImportDate  \
# 0          2025        AK     21989       HIOS  2024-08-29 01:02:15
# 1          2025        AK     21989       HIOS  2024-08-29 01:02:15
# 2          2025        AK     21989       HIOS  2024-08-29 01:02:15
# 3          2025        AK     21989       HIOS  2024-08-29 01:02:15
# 4          2025        AK     21989       HIOS  2024-08-29 01:02:15
#
#   StandardComponentId             PlanId                   BenefitName  \
# 0      21989AK0030001  21989AK0030001-00             Accidental Dental
# 1      21989AK0030001  21989AK0030001-00     Basic Dental Care - Adult
# 2      21989AK0030001  21989AK0030001-00     Basic Dental Care - Child
# 3      21989AK0030001  21989AK0030001-00  Dental Check-Up for Children
# 4      21989AK0030001  21989AK0030001-00     Major Dental Care - Adult
#
#     CopayInnTier1 CopayInnTier2  ... IsEHB IsCovered QuantLimitOnSvc LimitQty  \
# 0             NaN           NaN  ...   NaN       NaN             NaN      NaN
# 1  Not Applicable           NaN  ...   NaN   Covered             Yes   1100.0
# 2  Not Applicable           NaN  ...   Yes   Covered             NaN      NaN
# 3  Not Applicable           NaN  ...   Yes   Covered             NaN      NaN
# 4  Not Applicable           NaN  ...   NaN   Covered             Yes   1100.0
#
#           LimitUnit Exclusions                  Explanation  \
# 0               NaN        NaN                          NaN
# 1  Dollars per Year        NaN  See policy for other limits
# 2               NaN        NaN        See policy for limits
# 3               NaN        NaN        See policy for limits
# 4  Dollars per Year        NaN  See policy for other limits
#
#              EHBVarReason IsExclFromInnMOOP IsExclFromOonMOOP
# 0                     NaN               NaN               NaN
# 1                 Not EHB               Yes               Yes
# 2  Additional EHB Benefit                No                No
# 3  Additional EHB Benefit                No                No
# 4                 Not EHB               Yes               Yes
#
# [5 rows x 24 columns]
# === Plan_Attributes_PUF.csv ===
#    BusinessYear StateCode  IssuerId IssuerMarketPlaceMarketingName SourceName  \
# 0          2025        AK     21989         Delta Dental of Alaska       HIOS
# 1          2025        AK     21989         Delta Dental of Alaska       HIOS
# 2          2025        AK     21989         Delta Dental of Alaska       HIOS
# 3          2025        AK     21989         Delta Dental of Alaska       HIOS
# 4          2025        AK     21989         Delta Dental of Alaska       HIOS
#
#             ImportDate MarketCoverage DentalOnlyPlan StandardComponentId  \
# 0  2024-08-29 01:02:15     Individual            Yes      21989AK0030001
# 1  2024-08-29 01:02:15     Individual            Yes      21989AK0030001
# 2  2024-08-29 01:02:15     Individual            Yes      21989AK0050001
# 3  2024-08-29 01:02:15     Individual            Yes      21989AK0050001
# 4  2024-08-29 01:02:15     Individual            Yes      21989AK0050002
#
#             PlanMarketingName  ... TEHBDedOutOfNetFamilyPerPerson  \
# 0   Delta Dental Premier Plan  ...                            NaN
# 1   Delta Dental Premier Plan  ...                            NaN
# 2  Delta Dental PPO 1000 Plan  ...                            NaN
# 3  Delta Dental PPO 1000 Plan  ...                            NaN
# 4  Delta Dental PPO 1500 Plan  ...                            NaN
#
#   TEHBDedOutOfNetFamilyPerGroup TEHBDedCombInnOonIndividual  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
#
#   TEHBDedCombInnOonFamilyPerPerson TEHBDedCombInnOonFamilyPerGroup  \
# 0                              NaN                             NaN
# 1                              NaN                             NaN
# 2                              NaN                             NaN
# 3                              NaN                             NaN
# 4                              NaN                             NaN
#
#   IsHSAEligible HSAOrHRAEmployerContribution  \
# 0           NaN                          NaN
# 1           NaN                          NaN
# 2           NaN                          NaN
# 3           NaN                          NaN
# 4           NaN                          NaN
#
#   HSAOrHRAEmployerContributionAmount URLForSummaryofBenefitsCoverage  \
# 0                                NaN                             NaN
# 1                                NaN                             NaN
# 2                                NaN                             NaN
# 3                                NaN                             NaN
# 4                                NaN                             NaN
#
#                                         PlanBrochure
# 0  https://www.deltadentalak.com/-/media/deltaden...
# 1  https://www.deltadentalak.com/-/media/deltaden...
# 2  https://www.deltadentalak.com/-/media/deltaden...
# 3  https://www.deltadentalak.com/-/media/deltaden...
# 4  https://www.deltadentalak.com/-/media/deltaden...
#
# [5 rows x 151 columns]
# === Rate_PUF.csv ===
#    BusinessYear StateCode  IssuerId SourceName           ImportDate  \
# 0          2025        AK     21989       HIOS  2024-08-29 01:02:15
# 1          2025        AK     21989       HIOS  2024-08-29 01:02:15
# 2          2025        AK     21989       HIOS  2024-08-29 01:02:15
# 3          2025        AK     21989       HIOS  2024-08-29 01:02:15
# 4          2025        AK     21989       HIOS  2024-08-29 01:02:15
#
#   RateEffectiveDate RateExpirationDate          PlanId   RatingAreaId  \
# 0        2025-01-01         2025-12-31  21989AK0030001  Rating Area 1
# 1        2025-01-01         2025-12-31  21989AK0030001  Rating Area 1
# 2        2025-01-01         2025-12-31  21989AK0030001  Rating Area 1
# 3        2025-01-01         2025-12-31  21989AK0030001  Rating Area 1
# 4        2025-01-01         2025-12-31  21989AK0030001  Rating Area 1
#
#          Tobacco   Age  IndividualRate  IndividualTobaccoRate  Couple  \
# 0  No Preference  0-14            65.0                    NaN     NaN
# 1  No Preference    15            65.0                    NaN     NaN
# 2  No Preference    16            65.0                    NaN     NaN
# 3  No Preference    17            65.0                    NaN     NaN
# 4  No Preference    18            65.0                    NaN     NaN
#
#    PrimarySubscriberAndOneDependent  PrimarySubscriberAndTwoDependents  \
# 0                               NaN                                NaN
# 1                               NaN                                NaN
# 2                               NaN                                NaN
# 3                               NaN                                NaN
# 4                               NaN                                NaN
#
#    PrimarySubscriberAndThreeOrMoreDependents  CoupleAndOneDependent  \
# 0                                        NaN                    NaN
# 1                                        NaN                    NaN
# 2                                        NaN                    NaN
# 3                                        NaN                    NaN
# 4                                        NaN                    NaN
#
#    CoupleAndTwoDependents  CoupleAndThreeOrMoreDependents
# 0                     NaN                             NaN
# 1                     NaN                             NaN
# 2                     NaN                             NaN
# 3                     NaN                             NaN
# 4                     NaN                             NaN
# === service-area-puf.csv ===
#    BusinessYear StateCode  IssuerId SourceName           ImportDate  \
# 0          2025        AK     21989       HIOS  2024-08-29 01:02:15
# 1          2025        AK     21989       HIOS  2024-08-29 01:02:15
# 2          2025        AK     21989       HIOS  2024-08-29 01:02:15
# 3          2025        AK     21989       HIOS  2024-08-29 01:02:15
# 4          2025        AK     21989       HIOS  2024-08-29 01:02:15
#
#   ServiceAreaId              ServiceAreaName CoverEntireState  County  \
# 0        AKS001               Alaska Premier              Yes     NaN
# 1        AKS002                   Alaska PPO               No  2020.0
# 2        AKS002                   Alaska PPO               No  2090.0
# 3        AKS002                   Alaska PPO               No  2170.0
# 4        AKS003  Alaska Premier - Individual              Yes     NaN
#
#   PartialCounty ZipCodes PartialCountyJustification      MarketCoverage  \
# 0           NaN      NaN                        NaN  SHOP (Small Group)
# 1            No      NaN                        NaN  SHOP (Small Group)
# 2            No      NaN                        NaN  SHOP (Small Group)
# 3            No      NaN                        NaN  SHOP (Small Group)
# 4           NaN      NaN                        NaN          Individual
#
#   DentalOnlyPlan
# 0            Yes
# 1            Yes
# 2            Yes
# 3            Yes
# 4            Yes
# === Analysis: Rate_PUF.csv ===
# Shape: (2418441, 20)
#
# First 5 rows:
# Shape: (2418441, 20)
#
# First 5 rows:
#    BusinessYear StateCode  IssuerId SourceName           ImportDate  \
# 0          2025        AK     21989       HIOS  2024-08-29 01:02:15
# 1          2025        AK     21989       HIOS  2024-08-29 01:02:15
# 2          2025        AK     21989       HIOS  2024-08-29 01:02:15
# 3          2025        AK     21989       HIOS  2024-08-29 01:02:15
# 4          2025        AK     21989       HIOS  2024-08-29 01:02:15
#
#   RateEffectiveDate RateExpirationDate          PlanId   RatingAreaId  \
# 0        2025-01-01         2025-12-31  21989AK0030001  Rating Area 1
# 1        2025-01-01         2025-12-31  21989AK0030001  Rating Area 1
# 2        2025-01-01         2025-12-31  21989AK0030001  Rating Area 1
# 3        2025-01-01         2025-12-31  21989AK0030001  Rating Area 1
# 4        2025-01-01         2025-12-31  21989AK0030001  Rating Area 1
#
#          Tobacco   Age  IndividualRate  IndividualTobaccoRate  Couple  \
# 0  No Preference  0-14            65.0                    NaN     NaN
# 1  No Preference    15            65.0                    NaN     NaN
# 2  No Preference    16            65.0                    NaN     NaN
# 3  No Preference    17            65.0                    NaN     NaN
# 4  No Preference    18            65.0                    NaN     NaN
#
#    PrimarySubscriberAndOneDependent  PrimarySubscriberAndTwoDependents  \
# 0                               NaN                                NaN
# 1                               NaN                                NaN
# 2                               NaN                                NaN
# 3                               NaN                                NaN
# 4                               NaN                                NaN
#
#    PrimarySubscriberAndThreeOrMoreDependents  CoupleAndOneDependent  \
# 0                                        NaN                    NaN
# 1                                        NaN                    NaN
# 2                                        NaN                    NaN
# 3                                        NaN                    NaN
# 4                                        NaN                    NaN
#
#    CoupleAndTwoDependents  CoupleAndThreeOrMoreDependents
# 0                     NaN                             NaN
# 1                     NaN                             NaN
# 2                     NaN                             NaN
# 3                     NaN                             NaN
# 4                     NaN                             NaN
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2418441 entries, 0 to 2418440
# Data columns (total 20 columns):
#  #   Column                                     Dtype
# ---  ------                                     -----
#  0   BusinessYear                               int64
#  1   StateCode                                  object
#  2   IssuerId                                   int64
#  3   SourceName                                 object
#  4   ImportDate                                 object
#  5   RateEffectiveDate                          object
#  6   RateExpirationDate                         object
#  7   PlanId                                     object
#  8   RatingAreaId                               object
#  9   Tobacco                                    object
#  10  Age                                        object
#  11  IndividualRate                             float64
#  12  IndividualTobaccoRate                      float64
#  13  Couple                                     float64
#  14  PrimarySubscriberAndOneDependent           float64
#  15  PrimarySubscriberAndTwoDependents          float64
#  16  PrimarySubscriberAndThreeOrMoreDependents  float64
#  17  CoupleAndOneDependent                      float64
#  18  CoupleAndTwoDependents                     float64
#  19  CoupleAndThreeOrMoreDependents             float64
# dtypes: float64(9), int64(2), object(9)
# memory usage: 369.0+ MB
#
# Missing values (percent):
# CoupleAndThreeOrMoreDependents               99.975935
# CoupleAndTwoDependents                       99.975935
# CoupleAndOneDependent                        99.975935
# PrimarySubscriberAndThreeOrMoreDependents    99.975935
# PrimarySubscriberAndTwoDependents            99.975935
# PrimarySubscriberAndOneDependent             99.975935
# Couple                                       99.975935
# IndividualTobaccoRate                        48.977668
# Tobacco                                       0.024065
# dtype: float64
# Numeric summary (describe):
#                                                count          mean  \
# BusinessYear                               2418441.0   2025.000000
# IssuerId                                   2418441.0  48134.579972
# IndividualRate                             2418441.0    462.745531
# IndividualTobaccoRate                      1233945.0    814.140210
# Couple                                         582.0     84.195515
# PrimarySubscriberAndOneDependent               582.0     94.154691
# PrimarySubscriberAndTwoDependents              582.0    115.440619
# PrimarySubscriberAndThreeOrMoreDependents      582.0    115.602990
# CoupleAndOneDependent                          582.0    147.454777
# CoupleAndTwoDependents                         582.0    147.605979
# CoupleAndThreeOrMoreDependents                 582.0    147.749450
#
#                                                     std       min         25%  \
# BusinessYear                                   0.000000   2025.00   2025.0000
# IssuerId                                   25817.022775  10046.00  28856.0000
# IndividualRate                               571.506368      0.00     30.3600
# IndividualTobaccoRate                        471.354819    130.30    486.9600
# Couple                                        37.955132     20.67     58.8700
# PrimarySubscriberAndOneDependent              44.527228     26.24     60.0000
# PrimarySubscriberAndTwoDependents             40.824494     26.24     95.0000
# PrimarySubscriberAndThreeOrMoreDependents     41.065196     26.24     95.0000
# CoupleAndOneDependent                         63.686461     39.42     99.1425
# CoupleAndTwoDependents                        63.731694     39.42     99.1425
# CoupleAndThreeOrMoreDependents                63.872696     39.42     99.1425
#
#                                                  50%         75%       max
# BusinessYear                                2025.000   2025.0000   2025.00
# IssuerId                                   41047.000  68781.0000  99969.00
# IndividualRate                               410.570    684.5300   9999.00
# IndividualTobaccoRate                        672.540   1026.0000   5877.03
# Couple                                        73.710    121.3900    165.19
# PrimarySubscriberAndOneDependent              76.000    140.0700    190.61
# PrimarySubscriberAndTwoDependents            121.635    147.8900    190.61
# PrimarySubscriberAndThreeOrMoreDependents    121.635    147.9875    222.00
# CoupleAndOneDependent                        133.760    208.9300    284.32
# CoupleAndTwoDependents                       133.760    209.4100    284.32
# CoupleAndThreeOrMoreDependents               133.760    209.4100    284.32
# Top value counts for object columns (showing up to 10):
#
# Column: StateCode — unique=31
# StateCode
# FL    572526
# MI    243464
# OH    215016
# SC    208641
# TX    191454
# WI    159283
# IN    128112
# NC    118014
# AL     66020
# IL     61200
# Name: count, dtype: int64
# Column: SourceName — unique=2
# SourceName
# HIOS     1671926
# SERFF     746515
# Name: count, dtype: int64
# Column: ImportDate — unique=110
# ImportDate
# 2024-09-19 01:01:32    191352
# 2024-09-14 01:01:31    189108
# 2024-08-14 20:01:41    151980
# 2025-01-11 00:01:52    106590
# 2024-10-11 01:02:00    105774
# 2024-08-15 01:01:23     99425
# 2024-08-16 01:01:20     81345
# 2024-10-31 01:01:26     71196
# 2024-08-12 20:01:40     69582
# 2024-08-13 20:01:38     67850
# Name: count, dtype: int64
# Column: RateEffectiveDate — unique=4
# RateEffectiveDate
# 2025-01-01    2136507
# 2025-07-01      94250
# 2025-04-01      93842
# 2025-10-01      93842
# Name: count, dtype: int64
# Column: RateExpirationDate — unique=4
# RateExpirationDate
# 2025-12-31    2136507
# 2025-06-30      94250
# 2025-09-30      93842
# 2025-03-31      93842
# Name: count, dtype: int64
# Column: PlanId — unique=5734
# PlanId
# 92388TX0190001    5508
# 28856IN0190004    3468
# 86728OH0290001    3468
# 69051IN0110001    3468
# 86728OH0300004    3468
# 86728OH0300002    3468
# 86728OH0300001    3468
# 86728OH0290006    3468
# 86728OH0290005    3468
# 86728OH0290002    3468
# Name: count, dtype: int64
# Column: RatingAreaId — unique=67
# RatingAreaId
# Rating Area 1     175718
# Rating Area 4     155983
# Rating Area 3     154234
# Rating Area 2     143280
# Rating Area 5     136713
# Rating Area 6     132727
# Rating Area 7     106048
# Rating Area 8      99571
# Rating Area 10     94063
# Rating Area 11     90340
# Name: count, dtype: int64
# Column: Tobacco — unique=3
# Tobacco
# Tobacco User/Non-Tobacco User    1233945
# No Preference                    1183914
# NaN                                  582
# Name: count, dtype: int64
# Column: Age — unique=52
# Age
# 0-14    47409
# 15      47409
# 42      47409
# 43      47409
# 44      47409
# 45      47409
# 46      47409
# 47      47409
# 48      47409
# 49      47409
# Name: count, dtype: int64
# Found rate-like columns: ['RateEffectiveDate', 'RateExpirationDate', 'IndividualRate', 'IndividualTobaccoRate']
#
# Column RateEffectiveDate found but it's not numeric; showing value counts:
# RateEffectiveDate
# 2025-01-01    2136507
# 2025-07-01      94250
# 2025-04-01      93842
# 2025-10-01      93842
# Name: count, dtype: int64
# Column RateExpirationDate found but it's not numeric; showing value counts:
# RateExpirationDate
# 2025-12-31    2136507
# 2025-06-30      94250
# 2025-09-30      93842
# 2025-03-31      93842
# Name: count, dtype: int64
# Top 5 rows by IndividualRate:
#         IndividualRate  BusinessYear StateCode  IssuerId SourceName
# 124226          9999.0          2025        AZ     86830       HIOS
# 124227          9999.0          2025        AZ     86830       HIOS
# 124228          9999.0          2025        AZ     86830       HIOS
# 124229          9999.0          2025        AZ     86830       HIOS
# 124230          9999.0          2025        AZ     86830       HIOS
# Top 5 rows by IndividualTobaccoRate:
#          IndividualTobaccoRate  BusinessYear StateCode  IssuerId SourceName
# 2404619                5877.03          2025        WV     50328      SERFF
# 2399009                5863.64          2025        WV     50328      SERFF
# 2404874                5817.39          2025        WV     50328      SERFF
# 2399264                5804.14          2025        WV     50328      SERFF
# 2404618                5783.00          2025        WV     50328      SERFF
# Sample 5 rows with highest count of non-null numeric values:
#      BusinessYear StateCode  IssuerId SourceName           ImportDate  \
# 510          2025        AK     21989       HIOS  2024-08-29 01:02:15
# 511          2025        AK     21989       HIOS  2024-08-29 01:02:15
# 512          2025        AK     21989       HIOS  2024-08-29 01:02:15
# 513          2025        AK     21989       HIOS  2024-08-29 01:02:15
# 514          2025        AK     21989       HIOS  2024-08-29 01:02:15
#
#     RateEffectiveDate RateExpirationDate          PlanId   RatingAreaId  \
# 510        2025-07-01         2025-09-30  21989AK0080001  Rating Area 1
# 511        2025-04-01         2025-06-30  21989AK0080001  Rating Area 1
# 512        2025-01-01         2025-03-31  21989AK0080001  Rating Area 1
# 513        2025-10-01         2025-12-31  21989AK0080001  Rating Area 1
# 514        2025-10-01         2025-12-31  21989AK0080001  Rating Area 2
#
#     Tobacco            Age  IndividualRate  IndividualTobaccoRate  Couple  \
# 510     NaN  Family Option           54.45                    NaN  113.26
# 511     NaN  Family Option           53.79                    NaN  111.88
# 512     NaN  Family Option           53.13                    NaN  110.50
# 513     NaN  Family Option           55.12                    NaN  114.65
# 514     NaN  Family Option           52.36                    NaN  108.92
#
#      PrimarySubscriberAndOneDependent  PrimarySubscriberAndTwoDependents  \
# 510                            130.69                             130.69
# 511                            129.10                             129.10
# 512                            127.50                             127.50
# 513                            132.28                             132.28
# 514                            125.67                             125.67
#
#      PrimarySubscriberAndThreeOrMoreDependents  CoupleAndOneDependent  \
# 510                                     130.69                 194.95
# 511                                     129.10                 192.57
# 512                                     127.50                 190.20
# 513                                     132.28                 197.32
# 514                                     125.67                 187.46
#
#      CoupleAndTwoDependents  CoupleAndThreeOrMoreDependents
# 510                  194.95                          194.95
# 511                  192.57                          192.57
# 512                  190.20                          190.20
# 513                  197.32                          197.32
# 514                  187.46                          187.46

# %% [markdown]
# 推荐只使用：
#
# IndividualRate
#
# IndividualTobaccoRate
#
# Age
#
# RatingArea
#
# Plan attributes（来自 Plan PUF）
#
# 家庭字段可以在报告中注明 “not widely used in ACA pricing”
